# %%
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# <b>Before that we learned how to write our own Neural Network Model. But there was just one node hidden layer inside my model. To be able to create with multiple layer we apply chain rule to find changing effects of multiple layer equations.

# %%
plt.matshow(cv2.imread('Images/image7.png'))

# %% [markdown]
# <b>Here we can say the b value affects 28 to 1 the z equation (last summary equation) of neural network.
